# %% [markdown]
# <a href="https://colab.research.google.com/github/rizkyirw/MSIB/blob/main/Exercise_2_Data_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df_household = pd.read_csv("/content/drive/MyDrive/household.csv")

df_household.tail(10)
# Out:
#        receipt_id  receipts_item_id     purchase_time              category  \
# 71990     5706802          17353920    12/8/2017 9:52  Sugar/Flavored Syrup
# 71991     5810097          17673421  12/20/2017 22:24  Sugar/Flavored Syrup
# 71992     5619551          17101654   12/3/2017 19:02  Sugar/Flavored Syrup
# 71993     5658236          17205706   12/6/2017 10:25  Sugar/Flavored Syrup
# 71994     5918414          17993057  12/28/2017 14:03  Sugar/Flavored Syrup
# 71995     5909305          17998610   12/27/2017 9:20  Sugar/Flavored Syrup
# 71996     5736299          17432379  12/13/2017 19:52  Sugar/Flavored Syrup
# 71997     5901144          18263665   12/27/2017 8:03  Sugar/Flavored Syrup
# 71998     5660630          17222218   12/7/2017 12:29  Sugar/Flavored Syrup
# 71999     5808147          17658789  12/19/2017 18:59  Sugar/Flavored Syrup
#
#       sub_category       format  unit_price  discount  quantity yearmonth
# ...

# %%
#1. Buat kolom baru 'last_price' dengan valuenya berasal dari `unit_price*quantity*discount`
df_household['last_price'] =  df_household['unit_price']*df_household['quantity']*df_household['discount']

# %%
df_household.head()
# Out:
#    receipt_id  receipts_item_id    purchase_time category sub_category  \
# 0     9622257          32369294  7/22/2018 21:19     Rice         Rice
# 1     9446359          31885876  7/15/2018 16:17     Rice         Rice
# 2     9470290          31930241  7/15/2018 12:12     Rice         Rice
# 3     9643416          32418582   7/24/2018 8:27     Rice         Rice
# 4     9692093          32561236  7/26/2018 11:28     Rice         Rice
#
#         format  unit_price  discount  quantity yearmonth  last_price
# 0  supermarket    128000.0         0         1   2018-07         0.0
# 1   minimarket    102750.0         0         1   2018-07         0.0
# 2  supermarket     64000.0         0         3   2018-07         0.0
# 3   minimarket     65000.0         0         1   2018-07         0.0
# 4  supermarket    124500.0         0         1   2018-07         0.0

# %%
#2. Buat kolom baru 'test' dengan valuenya = 1
df_household['test'] = 1

# %%
df_household.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72000 entries, 0 to 71999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   receipt_id        72000 non-null  int64
#  1   receipts_item_id  72000 non-null  int64
#  2   purchase_time     72000 non-null  object
#  3   category          72000 non-null  object
#  4   sub_category      72000 non-null  object
#  5   format            72000 non-null  object
#  6   unit_price        72000 non-null  float64
#  7   discount          72000 non-null  int64
#  8   quantity          72000 non-null  int64
#  9   yearmonth         72000 non-null  object
#  10  last_price        72000 non-null  float64
#  11  test              72000 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 6.6+ MB

# %%
#3. Drop kolom test tersebut
df_household.drop('test', axis=1, inplace=True)

# %%
df_household.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72000 entries, 0 to 71999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   receipt_id        72000 non-null  int64
#  1   receipts_item_id  72000 non-null  int64
#  2   purchase_time     72000 non-null  object
#  3   category          72000 non-null  object
#  4   sub_category      72000 non-null  object
#  5   format            72000 non-null  object
#  6   unit_price        72000 non-null  float64
#  7   discount          72000 non-null  int64
#  8   quantity          72000 non-null  int64
#  9   yearmonth         72000 non-null  object
#  10  last_price        72000 non-null  float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 6.0+ MB

# %%
#4. Drop rows 5 baris terakhir
df_household.drop(df_household.index[-5:])
# Out:
#        receipt_id  receipts_item_id     purchase_time              category  \
# 0         9622257          32369294   7/22/2018 21:19                  Rice
# 1         9446359          31885876   7/15/2018 16:17                  Rice
# 2         9470290          31930241   7/15/2018 12:12                  Rice
# 3         9643416          32418582    7/24/2018 8:27                  Rice
# 4         9692093          32561236   7/26/2018 11:28                  Rice
# ...           ...               ...               ...                   ...
# 71990     5706802          17353920    12/8/2017 9:52  Sugar/Flavored Syrup
# 71991     5810097          17673421  12/20/2017 22:24  Sugar/Flavored Syrup
# 71992     5619551          17101654   12/3/2017 19:02  Sugar/Flavored Syrup
# 71993     5658236          17205706   12/6/2017 10:25  Sugar/Flavored Syrup
# 71994     5918414          17993057  12/28/2017 14:03  Sugar/Flavored Syrup
#
# ...

# %%
df_household.index[-5:]
# Out:
# RangeIndex(start=71995, stop=72000, step=1)

# %%
df_household.tail()
# Out:
#        receipt_id  receipts_item_id     purchase_time              category  \
# 71995     5909305          17998610   12/27/2017 9:20  Sugar/Flavored Syrup
# 71996     5736299          17432379  12/13/2017 19:52  Sugar/Flavored Syrup
# 71997     5901144          18263665   12/27/2017 8:03  Sugar/Flavored Syrup
# 71998     5660630          17222218   12/7/2017 12:29  Sugar/Flavored Syrup
# 71999     5808147          17658789  12/19/2017 18:59  Sugar/Flavored Syrup
#
#       sub_category       format  unit_price  discount  quantity yearmonth  \
# 71995        Sugar   minimarket     25000.0         0         1   2017-12
# 71996        Sugar   minimarket     12500.0         0         1   2017-12
# 71997        Sugar   minimarket     12500.0         0         1   2017-12
# 71998        Sugar  hypermarket     12500.0         0         3   2017-12
# 71999        Sugar   minimarket     12500.0         0         3   2017-12
#
#        last_price
# 71995         0.0
# 71996         0.0
# ...

# %%
# 4. Cara 2
df_household.drop([71995, 71996, 71997, 71998, 71999], axis=0, inplace=True)
df_household.head()

df_household.drop
# Out:
# <bound method DataFrame.drop of        receipt_id  receipts_item_id     purchase_time              category  \
# 0         9622257          32369294   7/22/2018 21:19                  Rice
# 1         9446359          31885876   7/15/2018 16:17                  Rice
# 2         9470290          31930241   7/15/2018 12:12                  Rice
# 3         9643416          32418582    7/24/2018 8:27                  Rice
# 4         9692093          32561236   7/26/2018 11:28                  Rice
# ...           ...               ...               ...                   ...
# 71990     5706802          17353920    12/8/2017 9:52  Sugar/Flavored Syrup
# 71991     5810097          17673421  12/20/2017 22:24  Sugar/Flavored Syrup
# 71992     5619551          17101654   12/3/2017 19:02  Sugar/Flavored Syrup
# 71993     5658236          17205706   12/6/2017 10:25  Sugar/Flavored Syrup
# 71994     5918414          17993057  12/28/2017 14:03  Sugar/Flavored Syrup
#
# ...

# %%
# Filter table based on value -> df_household[tulis kondisinya: select_kolom ==/>/</!=/dll <value>]

# %%
#select_kolom ==/>/</!=/dll <value>

df_household['quantity'] > 4
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 71990    False
# 71991    False
# 71992    False
# 71993    False
# 71994    False
# Name: quantity, Length: 71995, dtype: bool

# %%
#tolong drop data dari table df_household ketika quantitynya lebih dari 5

test3 = df_household[df_household['quantity'] < 5]
test3
# Out:
#        receipt_id  receipts_item_id     purchase_time              category  \
# 0         9622257          32369294   7/22/2018 21:19                  Rice
# 1         9446359          31885876   7/15/2018 16:17                  Rice
# 2         9470290          31930241   7/15/2018 12:12                  Rice
# 3         9643416          32418582    7/24/2018 8:27                  Rice
# 4         9692093          32561236   7/26/2018 11:28                  Rice
# ...           ...               ...               ...                   ...
# 71990     5706802          17353920    12/8/2017 9:52  Sugar/Flavored Syrup
# 71991     5810097          17673421  12/20/2017 22:24  Sugar/Flavored Syrup
# 71992     5619551          17101654   12/3/2017 19:02  Sugar/Flavored Syrup
# 71993     5658236          17205706   12/6/2017 10:25  Sugar/Flavored Syrup
# 71994     5918414          17993057  12/28/2017 14:03  Sugar/Flavored Syrup
#
# ...

# %%
#5. Drop value ketika last_price nya kurang dari 10000
df_household = df_household[df_household['last_price'] >= 10000]
df_household
# Out:
#        receipt_id  receipts_item_id     purchase_time              category  \
# 23        9767244          32763935    7/29/2018 8:25                  Rice
# 43        9483559          31978405   7/16/2018 16:24                  Rice
# 48        9841041          33010608    7/29/2018 8:21                  Rice
# 55        9284943          31450853    7/6/2018 12:05                  Rice
# 72        9853312          33070898   7/30/2018 13:54                  Rice
# ...           ...               ...               ...                   ...
# 71935     5737076          17437723  12/13/2017 14:13  Sugar/Flavored Syrup
# 71941     5613876          17044297   12/3/2017 16:33  Sugar/Flavored Syrup
# 71956     5681770          17293166   12/8/2017 11:16  Sugar/Flavored Syrup
# 71970     5872479          17910741  12/24/2017 13:14  Sugar/Flavored Syrup
# 71977     5678339          17317824   12/8/2017 17:11  Sugar/Flavored Syrup
#
# ...
